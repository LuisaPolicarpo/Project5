# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisaPolicarpo/Project5/blob/main/Time_series_s_e_g.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
df_earnings_final = pd.read_csv("https://raw.githubusercontent.com/LuisaPolicarpo/Project5/main/Dataset/earnings.csv")
import googletrans

from googletrans import Translator
translator = Translator()
month = 'Maio'

print(translator.translate(month,src='pt', dest='en').text)

df_earnings_final_months = df_earnings_final['Date'].str.split('de', expand=True)
df_earnings_final_months.rename(columns = ({0: "month", 1: "year"}),inplace=True)
df_earnings_final_months['month'] = df_earnings_final_months['month'].apply(lambda month: translator.translate(month,src='pt', dest='en').text)
# Out:
# May

# %%
import pandas as pd

# %%
df_earnings_final
# Out:
#      Unnamed: 0                                    Type               Date  \
# 0             0                               Hotelaria   Dezembro de 2021
# 1             1                               Hotelaria   Novembro de 2021
# 2             2                               Hotelaria    Outubro de 2021
# 3             3                               Hotelaria   Setembro de 2021
# 4             4                               Hotelaria     Agosto de 2021
# ..          ...                                     ...                ...
# 175         175  Turismo no espaço rural e de habitação       Maio de 2017
# 176         176  Turismo no espaço rural e de habitação      Abril de 2017
# 177         177  Turismo no espaço rural e de habitação      Março de 2017
# 178         178  Turismo no espaço rural e de habitação  Fevereiro de 2017
# 179         179  Turismo no espaço rural e de habitação    Janeiro de 2017
#
#       Value
# 0    132228
# 1    185160
# 2    295076
# 3    309314
# ...

# %%
df_earnings_final_data = df_earnings_final.drop(columns=['Unnamed: 0'])

# %%
df_earnings_final_data
# Out:
#                                        Type               Date   Value
# 0                                 Hotelaria   Dezembro de 2021  132228
# 1                                 Hotelaria   Novembro de 2021  185160
# 2                                 Hotelaria    Outubro de 2021  295076
# 3                                 Hotelaria   Setembro de 2021  309314
# 4                                 Hotelaria     Agosto de 2021  444303
# ..                                      ...                ...     ...
# 175  Turismo no espaço rural e de habitação       Maio de 2017    7713
# 176  Turismo no espaço rural e de habitação      Abril de 2017    7305
# 177  Turismo no espaço rural e de habitação      Março de 2017    3765
# 178  Turismo no espaço rural e de habitação  Fevereiro de 2017    2981
# 179  Turismo no espaço rural e de habitação    Janeiro de 2017    2533
#
# [180 rows x 3 columns]

# %%
df_earnings_final_data
# Out:
#                                        Type               Date   Value
# 0                                 Hotelaria   Dezembro de 2021  132228
# 1                                 Hotelaria   Novembro de 2021  185160
# 2                                 Hotelaria    Outubro de 2021  295076
# 3                                 Hotelaria   Setembro de 2021  309314
# 4                                 Hotelaria     Agosto de 2021  444303
# ..                                      ...                ...     ...
# 175  Turismo no espaço rural e de habitação       Maio de 2017    7713
# 176  Turismo no espaço rural e de habitação      Abril de 2017    7305
# 177  Turismo no espaço rural e de habitação      Março de 2017    3765
# 178  Turismo no espaço rural e de habitação  Fevereiro de 2017    2981
# 179  Turismo no espaço rural e de habitação    Janeiro de 2017    2533
#
# [180 rows x 3 columns]

# %%
df_earnings_final_months
# Out:
#          month   year
# 0     December   2021
# 1     November   2021
# 2      October   2021
# 3    September   2021
# 4       August   2021
# ..         ...    ...
# 175        May   2017
# 176      April   2017
# 177      March   2017
# 178   February   2017
# 179    January   2017
#
# [180 rows x 2 columns]

# %%
df_earnings_v1= pd.concat([df_earnings_final_months,df_earnings_final_data], axis=1, join="outer")

# %%
df_earnings = df_earnings_v1.drop(columns=['Date'])

# %%
df_earnings
# Out:
#          month   year                                    Type   Value
# 0     December   2021                               Hotelaria  132228
# 1     November   2021                               Hotelaria  185160
# 2      October   2021                               Hotelaria  295076
# 3    September   2021                               Hotelaria  309314
# 4       August   2021                               Hotelaria  444303
# ..         ...    ...                                     ...     ...
# 175        May   2017  Turismo no espaço rural e de habitação    7713
# 176      April   2017  Turismo no espaço rural e de habitação    7305
# 177      March   2017  Turismo no espaço rural e de habitação    3765
# 178   February   2017  Turismo no espaço rural e de habitação    2981
# 179    January   2017  Turismo no espaço rural e de habitação    2533
#
# [180 rows x 4 columns]

# %%
df_earnings.rename(columns = {'Value': 'Earnings'}, inplace = True)

# %%
df_earnings
# Out:
#          month   year                                    Type  Earnings
# 0     December   2021                               Hotelaria    132228
# 1     November   2021                               Hotelaria    185160
# 2      October   2021                               Hotelaria    295076
# 3    September   2021                               Hotelaria    309314
# 4       August   2021                               Hotelaria    444303
# ..         ...    ...                                     ...       ...
# 175        May   2017  Turismo no espaço rural e de habitação      7713
# 176      April   2017  Turismo no espaço rural e de habitação      7305
# 177      March   2017  Turismo no espaço rural e de habitação      3765
# 178   February   2017  Turismo no espaço rural e de habitação      2981
# 179    January   2017  Turismo no espaço rural e de habitação      2533
#
# [180 rows x 4 columns]

# %%
# from google.colab import files
# df_earnings.to_csv('earnings_lv.csv') 
# files.download('earnings_lv.csv')

# %%
df_guest_1 = pd.read_csv("https://raw.githubusercontent.com/LuisaPolicarpo/Project5/main/Dataset/guests.csv")

# %%
df_guest_1
# Out:
#      Unnamed: 0                                    Type               Date  \
# 0             0                               Hotelaria   Dezembro de 2021
# 1             1                               Hotelaria   Novembro de 2021
# 2             2                               Hotelaria    Outubro de 2021
# 3             3                               Hotelaria   Setembro de 2021
# 4             4                               Hotelaria     Agosto de 2021
# ..          ...                                     ...                ...
# 175         175  Turismo no espaço rural e de habitação       Maio de 2017
# 176         176  Turismo no espaço rural e de habitação      Abril de 2017
# 177         177  Turismo no espaço rural e de habitação      Março de 2017
# 178         178  Turismo no espaço rural e de habitação  Fevereiro de 2017
# 179         179  Turismo no espaço rural e de habitação    Janeiro de 2017
#
#        Value
# 0     897016
# 1    1179545
# 2    1728722
# ...

# %%
df_guest_final_months = df_guest_1['Date'].str.split('de', expand=True)

# %%
df_guest_final_months
# Out:
#               0      1
# 0     Dezembro    2021
# 1     Novembro    2021
# 2      Outubro    2021
# 3     Setembro    2021
# 4       Agosto    2021
# ..          ...    ...
# 175       Maio    2017
# 176      Abril    2017
# 177      Março    2017
# 178  Fevereiro    2017
# 179    Janeiro    2017
#
# [180 rows x 2 columns]

# %%
df_guest_final_months .rename(columns = ({0: "month", 1: "year"}),inplace=True)

# %%
# df_guest_final_months['month'] = df_guest_final_months['month'].apply(lambda month: translator.translate(month,src='pt', dest='en').text)

# %%
df_guest_final_months
# Out:
#           month   year
# 0     Dezembro    2021
# 1     Novembro    2021
# 2      Outubro    2021
# 3     Setembro    2021
# 4       Agosto    2021
# ..          ...    ...
# 175       Maio    2017
# 176      Abril    2017
# 177      Março    2017
# 178  Fevereiro    2017
# 179    Janeiro    2017
#
# [180 rows x 2 columns]

# %%
df_guests_v1= pd.concat([df_guest_1,df_guest_final_months], axis=1, join="outer")

# %%
df_guests_v1
# Out:
#      Unnamed: 0                                    Type               Date  \
# 0             0                               Hotelaria   Dezembro de 2021
# 1             1                               Hotelaria   Novembro de 2021
# 2             2                               Hotelaria    Outubro de 2021
# 3             3                               Hotelaria   Setembro de 2021
# 4             4                               Hotelaria     Agosto de 2021
# ..          ...                                     ...                ...
# 175         175  Turismo no espaço rural e de habitação       Maio de 2017
# 176         176  Turismo no espaço rural e de habitação      Abril de 2017
# 177         177  Turismo no espaço rural e de habitação      Março de 2017
# 178         178  Turismo no espaço rural e de habitação  Fevereiro de 2017
# 179         179  Turismo no espaço rural e de habitação    Janeiro de 2017
#
#        Value       month   year
# 0     897016   Dezembro    2021
# ...

# %%
df_guests = df_guests_v1.drop(columns=['Unnamed: 0','Date'])

# %%
df_guests.rename(columns = {'Value':'Guests'}, inplace=True)

# %%
df_guests
# Out:
#                                        Type   Guests       month   year
# 0                                 Hotelaria   897016   Dezembro    2021
# 1                                 Hotelaria  1179545   Novembro    2021
# 2                                 Hotelaria  1728722    Outubro    2021
# 3                                 Hotelaria  1626039   Setembro    2021
# 4                                 Hotelaria  1957735     Agosto    2021
# ..                                      ...      ...         ...    ...
# 175  Turismo no espaço rural e de habitação    68093       Maio    2017
# 176  Turismo no espaço rural e de habitação    75208      Abril    2017
# 177  Turismo no espaço rural e de habitação    37245      Março    2017
# 178  Turismo no espaço rural e de habitação    32497  Fevereiro    2017
# 179  Turismo no espaço rural e de habitação    24434    Janeiro    2017
#
# [180 rows x 4 columns]

# %%
# from google.colab import files
# df_guests.to_csv('guests_lv.csv') 
# files.download('guests_lv.csv')

# %%
df_sleeps_1 = pd.read_csv("https://raw.githubusercontent.com/LuisaPolicarpo/Project5/main/Dataset/sleeps.csv")

# %%
df_sleeps_1
# Out:
#      Unnamed: 0                                    Type               Date  \
# 0             0                               Hotelaria   Dezembro de 2021
# 1             1                               Hotelaria   Novembro de 2021
# 2             2                               Hotelaria    Outubro de 2021
# 3             3                               Hotelaria   Setembro de 2021
# 4             4                               Hotelaria     Agosto de 2021
# ..          ...                                     ...                ...
# 175         175  Turismo no espaço rural e de habitação       Maio de 2017
# 176         176  Turismo no espaço rural e de habitação      Abril de 2017
# 177         177  Turismo no espaço rural e de habitação      Março de 2017
# 178         178  Turismo no espaço rural e de habitação  Fevereiro de 2017
# 179         179  Turismo no espaço rural e de habitação    Janeiro de 2017
#
#        Value
# 0    2067266
# 1    2936910
# 2    4568205
# ...

# %%
df_sleeps_final_months = df_sleeps_1['Date'].str.split('de', expand=True)

# %%
df_sleeps_final_months.rename(columns = ({0: "month", 1: "year"}),inplace=True)

# %%
df_sleeps_final_months
# Out:
#           month   year
# 0     Dezembro    2021
# 1     Novembro    2021
# 2      Outubro    2021
# 3     Setembro    2021
# 4       Agosto    2021
# ..          ...    ...
# 175       Maio    2017
# 176      Abril    2017
# 177      Março    2017
# 178  Fevereiro    2017
# 179    Janeiro    2017
#
# [180 rows x 2 columns]

# %%
# df_sleeps_final_months['month'] = df_sleeps_final_months['month'].apply(lambda month: translator.translate(month,src='pt', dest='en').text)

# %%
df_sleeps_v1= pd.concat([df_sleeps_1,df_sleeps_final_months], axis=1, join="outer")

# %%
df_sleeps = df_sleeps_v1.drop(columns=['Date','Unnamed: 0'])

# %%
df_sleeps.rename(columns = {'Value': 'sleeps'}, inplace = True)

# %%
df_sleeps = pd.read_csv("https://raw.githubusercontent.com/LuisaPolicarpo/Project5/main/Dataset/sleeps_lv.csv")

# %%
df_sleeps
# Out:
#      Unnamed: 0                                    Type  Earnings      month  \
# 0             0                               Hotelaria   2067266   December
# 1             1                               Hotelaria   2936910   November
# 2             2                               Hotelaria   4568205    October
# 3             3                               Hotelaria   4592006  September
# 4             4                               Hotelaria   6077677     August
# ..          ...                                     ...       ...        ...
# 175         175  Turismo no espaço rural e de habitação    133812        May
# 176         176  Turismo no espaço rural e de habitação    148148      April
# 177         177  Turismo no espaço rural e de habitação     68090      March
# 178         178  Turismo no espaço rural e de habitação     58722   February
# 179         179  Turismo no espaço rural e de habitação     42290    January
#
#      year
# 0    2021
# 1    2021
# ...

# %%
df_sleeps_2 = df_sleeps.drop(columns=['Unnamed: 0','month','year','Type'])

# %%
df_sleeps_2
# Out:
#      Earnings
# 0     2067266
# 1     2936910
# 2     4568205
# 3     4592006
# 4     6077677
# ..        ...
# 175    133812
# 176    148148
# 177     68090
# 178     58722
# 179     42290
#
# [180 rows x 1 columns]

# %%
df_final_v1= pd.concat([df_earnings,df_sleeps_2], axis=1, join="outer")

# %%
df_final_v1
# Out:
#          month   year                                    Type  Earnings  \
# 0     December   2021                               Hotelaria    132228
# 1     November   2021                               Hotelaria    185160
# 2      October   2021                               Hotelaria    295076
# 3    September   2021                               Hotelaria    309314
# 4       August   2021                               Hotelaria    444303
# ..         ...    ...                                     ...       ...
# 175        May   2017  Turismo no espaço rural e de habitação      7713
# 176      April   2017  Turismo no espaço rural e de habitação      7305
# 177      March   2017  Turismo no espaço rural e de habitação      3765
# 178   February   2017  Turismo no espaço rural e de habitação      2981
# 179    January   2017  Turismo no espaço rural e de habitação      2533
#
#      Earnings
# 0     2067266
# 1     2936910
# 2     4568205
# 3     4592006
# 4     6077677
# ...

# %%
df_guests
# Out:
#                                        Type   Guests       month   year
# 0                                 Hotelaria   897016   Dezembro    2021
# 1                                 Hotelaria  1179545   Novembro    2021
# 2                                 Hotelaria  1728722    Outubro    2021
# 3                                 Hotelaria  1626039   Setembro    2021
# 4                                 Hotelaria  1957735     Agosto    2021
# ..                                      ...      ...         ...    ...
# 175  Turismo no espaço rural e de habitação    68093       Maio    2017
# 176  Turismo no espaço rural e de habitação    75208      Abril    2017
# 177  Turismo no espaço rural e de habitação    37245      Março    2017
# 178  Turismo no espaço rural e de habitação    32497  Fevereiro    2017
# 179  Turismo no espaço rural e de habitação    24434    Janeiro    2017
#
# [180 rows x 4 columns]

# %%
df_guests_2 = df_guests.drop(columns=['month','year','Type'])

# %%
df_guests_2
# Out:
#       Guests
# 0     897016
# 1    1179545
# 2    1728722
# 3    1626039
# 4    1957735
# ..       ...
# 175    68093
# 176    75208
# 177    37245
# 178    32497
# 179    24434
#
# [180 rows x 1 columns]

# %%
df_final_v2= pd.concat([df_final_v1,df_guests_2 ], axis=1, join="outer")

# %%
df_final_v2
# Out:
#          month   year                                    Type  Earnings  \
# 0     December   2021                               Hotelaria    132228
# 1     November   2021                               Hotelaria    185160
# 2      October   2021                               Hotelaria    295076
# 3    September   2021                               Hotelaria    309314
# 4       August   2021                               Hotelaria    444303
# ..         ...    ...                                     ...       ...
# 175        May   2017  Turismo no espaço rural e de habitação      7713
# 176      April   2017  Turismo no espaço rural e de habitação      7305
# 177      March   2017  Turismo no espaço rural e de habitação      3765
# 178   February   2017  Turismo no espaço rural e de habitação      2981
# 179    January   2017  Turismo no espaço rural e de habitação      2533
#
#      Earnings   Guests
# 0     2067266   897016
# 1     2936910  1179545
# 2     4568205  1728722
# ...

# %%
import pandas as pd
import itertools
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import matplotlib
from statsmodels.tsa.stattools import kpss

# %%
from google.colab import files
df_final_v2.to_csv('final.csv') 
files.download('final.csv')

# %%
df_final_v2 = pd.read_csv('https://raw.githubusercontent.com/LuisaPolicarpo/Project5/main/Dataset/final%20(2).csv')

# %%
df_final_v2
# Out:
#      Unnamed: 0      month  year                                    Type  \
# 0             0   December  2021                               Hotelaria
# 1             1   November  2021                               Hotelaria
# 2             2    October  2021                               Hotelaria
# 3             3  September  2021                               Hotelaria
# 4             4     August  2021                               Hotelaria
# ..          ...        ...   ...                                     ...
# 175         175        May  2017  Turismo no espaço rural e de habitação
# 176         176      April  2017  Turismo no espaço rural e de habitação
# 177         177      March  2017  Turismo no espaço rural e de habitação
# 178         178   February  2017  Turismo no espaço rural e de habitação
# 179         179    January  2017  Turismo no espaço rural e de habitação
#
#      Earnings   sleeps   Guests
# 0      132228  2067266   897016
# ...

# %%
months = {'January':'01', 'February':'02', 'March':'03', 'April':'04', 'May':'05', 'June':'06', 'July':'07', 'August':'08', 'September':'09', 'October':10, 'November':11, 'December':12}
df_final_v2_1=df_final_v2.replace({"month": months})
df_final_v2_1['year'] = df_final_v2_1['year'].astype(str)
df_final_v2_1['month'] = df_final_v2_1['month'].astype(str)
df_final_v2_1['Date'] = df_final_v2_1['month'] + df_final_v2_1['year']
df_final = df_final_v2_1[['Date', 'Type','Earnings','sleeps','Guests']]
df_final['Date'] = pd.to_datetime(df_final['Date'], format='%m%Y')
df_final.sort_values(by='Date', ascending=True).set_index('Date')
# Out:
# <ipython-input-209-6600cb937121>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Date'] = pd.to_datetime(df_final['Date'], format='%m%Y')
#                                               Type  Earnings   sleeps   Guests
# Date
# 2017-01-01  Turismo no espaço rural e de habitação      2533    42290    24434
# 2017-01-01                               Hotelaria    119518  2304534   931993
# 2017-01-01                        Alojamento local      9882   311023   142825
# 2017-02-01                               Hotelaria    133906  2675899  1029355
# 2017-02-01                        Alojamento local     10369   346405   156477
# ...                                            ...       ...      ...      ...
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      180 non-null    datetime64[ns]
#  1   Type      180 non-null    object
#  2   Earnings  180 non-null    int64
#  3   sleeps    180 non-null    int64
#  4   Guests    180 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 7.2+ KB

# %%
df_final2_2019 = df_final[df_final['Date']<'2020-01-01'].sort_values(by='Date', ascending=True).set_index('Date')
df_final2_2019
# Out:
#                                               Type  Earnings   sleeps   Guests
# Date
# 2017-01-01  Turismo no espaço rural e de habitação      2533    42290    24434
# 2017-01-01                               Hotelaria    119518  2304534   931993
# 2017-01-01                        Alojamento local      9882   311023   142825
# 2017-02-01                               Hotelaria    133906  2675899  1029355
# 2017-02-01                        Alojamento local     10369   346405   156477
# ...                                            ...       ...      ...      ...
# 2019-11-01  Turismo no espaço rural e de habitação      5451    85965    48134
# 2019-11-01                               Hotelaria    204789  3392912  1426861
# 2019-12-01                        Alojamento local     18567   539947   260248
# 2019-12-01  Turismo no espaço rural e de habitação      5346    80837    42967
# 2019-12-01                               Hotelaria    181357  2895156  1275651
#
# ...

# %%
df_final2_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 108 entries, 2017-01-01 to 2019-12-01
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      108 non-null    object
#  1   Earnings  108 non-null    int64
#  2   sleeps    108 non-null    int64
#  3   Guests    108 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 4.2+ KB

# %%
df_final2 = df_final2_2019.groupby(['Date']).agg({'Earnings':'sum', 'sleeps':'sum', 'Guests':'sum'})

# %%
df_final2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2017-01-01 to 2019-12-01
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Earnings  36 non-null     int64
#  1   sleeps    36 non-null     int64
#  2   Guests    36 non-null     int64
# dtypes: int64(3)
# memory usage: 1.1 KB

# %%
df_final2.corr()
# Out:
#           Earnings    sleeps    Guests
# Earnings  1.000000  0.992755  0.984199
# sleeps    0.992755  1.000000  0.986030
# Guests    0.984199  0.986030  1.000000

# %%
pip install --upgrade --no-deps statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import statsmodels.api

# %%
df_final2  ['Earnings'].plot(figsize = (25,5))
df_final2  ['Earnings'].rolling(12, min_periods = 2).mean().plot(figsize = (25,5))

# %%
df_final2 ['sleeps'].plot(figsize = (25,5))
df_final2  ['sleeps'].rolling(7, min_periods = 2).mean().plot(figsize = (25,5))

# %%
df_final2  ['Guests'].plot(figsize = (25,5))
df_final2  ['Guests'].rolling(14, min_periods = 2).mean().plot(figsize = (25,5))

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition_earnings = sm.tsa.seasonal_decompose(x = df_final2['Earnings'].rolling(14).mean().dropna(), period = 5, model='additive')
fig = decomposition_earnings.plot()
plt.show()

# %%
decomposition_Earnings_final = sm.tsa.seasonal_decompose(x = (df_final2 ['Earnings'] - decomposition_earnings.seasonal).dropna(), freq = 11, model='additive')
fig = decomposition_Earnings_final.plot()
plt.plot()
# Out:
# <ipython-input-222-08b697012a20>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition_Earnings_final = sm.tsa.seasonal_decompose(x = (df_final2 ['Earnings'] - decomposition_earnings.seasonal).dropna(), freq = 11, model='additive')
# []

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition_sleeps = sm.tsa.seasonal_decompose(x = df_final2 ['sleeps'].rolling(12).mean().dropna(), period = 7, model='additive')
fig = decomposition_sleeps.plot()
plt.show()

# %%
decomposition_sleeps_final = sm.tsa.seasonal_decompose(x = (df_final2 ['sleeps'] - decomposition_sleeps.seasonal).dropna(), freq = 12, model='additive')
fig = decomposition_sleeps_final.plot()
plt.plot()
# Out:
# <ipython-input-224-66b11eab10ee>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition_sleeps_final = sm.tsa.seasonal_decompose(x = (df_final2 ['sleeps'] - decomposition_sleeps.seasonal).dropna(), freq = 12, model='additive')
# []

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition_Guests = sm.tsa.seasonal_decompose(x = df_final2['Guests'].rolling(12).mean().dropna(), period = 5, model='additive')
fig = decomposition_Guests.plot()
plt.show()

# %%
decomposition_Guests_final = sm.tsa.seasonal_decompose(x = (df_final2 ['Guests'] - decomposition_Guests.seasonal).dropna(), freq = 12, model='additive')
fig = decomposition_Guests_final.plot()
plt.plot()
# Out:
# <ipython-input-226-d38a4aaaa9c2>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition_Guests_final = sm.tsa.seasonal_decompose(x = (df_final2 ['Guests'] - decomposition_Guests.seasonal).dropna(), freq = 12, model='additive')
# []

# %%
from sklearn.linear_model import LinearRegression

# %%
# !pip install pmdarima
from pmdarima.arima import auto_arima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np

# %%
df_final2['Earnings'].autocorr()
# Out:
# 0.8180313421645462

# %%
kpss(df_final2['Earnings'], regression='c', nlags = 'auto')
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   Returns
# (0.10849837613250617,
#  0.1,
#  3,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
kpss(df_final2['Guests'], regression='c', nlags = 'auto')
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   Returns
# (0.1287604680593107,
#  0.1,
#  3,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
kpss(df_final2['sleeps'], regression='c', nlags = 'auto')
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   Returns
# (0.0738290806086046,
#  0.1,
#  3,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
from statsmodels.tsa.api import ExponentialSmoothing

test_size_percentage = 0.25
test_size = int(test_size_percentage * df_final2.shape[0])
train_size_initial = df_final2.shape[0] - test_size

train_set = df_final2['sleeps'].iloc[:train_size_initial]
test_set = df_final2['sleeps'].iloc[train_size_initial:]


def expsm_forecast(tme_sries):
  es = ExponentialSmoothing(tme_sries).fit(smoothing_level=0.1)
  return es.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_es = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_es['test'] = list(test_set)
evaluation_df_es['forecast'] = evaluation_df_es['forecast']\
  .apply(lambda n: expsm_forecast(df_final2['sleeps'].iloc[:train_size_initial + n]))
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   return self._initialize_heuristic()
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   # Negative indices (that lie in the Index)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# ...

# %%
df_final2 ['sleeps'].plot()
evaluation_df_es.set_index(test_set.index)['forecast'].plot()

# %%
test_size_percentage = 0.20
test_size = int(test_size_percentage * df_final2.shape[0])
train_size_initial = df_final2.shape[0] - test_size

train_set = df_final2['sleeps'].iloc[:train_size_initial]
test_set = df_final2['sleeps'].iloc[train_size_initial:]


def arima_forecast(tme_sries):
  arima = ARIMA(tme_sries, order=(1, 0, 2)).fit()
  return arima.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_ar = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_ar['test'] = list(test_set)
evaluation_df_ar['forecast'] = evaluation_df_ar['forecast']\
  .apply(lambda n: arima_forecast(df_final2['sleeps'].iloc[:train_size_initial + 6]))
# Out:
# Date
# 2017-01-01    2657847
# 2017-02-01    3081026
# 2017-03-01    4015775
# 2017-04-01    5706131
# 2017-05-01    6002029
# 2017-06-01    6716372
# 2017-07-01    7841656
# 2017-08-01    9021656
# 2017-09-01    7194693
# 2017-10-01    6071385
# 2017-11-01    3537490
# 2017-12-01    3119681
# 2018-01-01    2843739
# 2018-02-01    3332670
# 2018-03-01    4571119
# 2018-04-01    5374612
# 2018-05-01    6302074
# 2018-06-01    6743203
# 2018-07-01    7974521
# 2018-08-01    9292740
# 2018-09-01    7342627
# 2018-10-01    6250714
# 2018-11-01    3791610
# 2018-12-01    3256830
# 2019-01-01    3034284
# 2019-02-01    3365240
# 2019-03-01    4606922
# 2019-04-01    5981300
# 2019-05-01    6557840
# Name: sleeps, dtype: int64
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# ...

# %%
df_final2 ['sleeps'].iloc[df_final2.shape[0] - 50:].plot()
evaluation_df_ar.set_index(test_set.index)['forecast'].iloc[evaluation_df_ar.shape[0] - 50:].plot()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
test_size_percentage = 0.75
test_size = int(test_size_percentage * df_final2.shape[0])
train_size_initial = df_final2.shape[0] - test_size

train_set = df_final2['sleeps'].iloc[:train_size_initial]
test_set = df_final2['sleeps'].iloc[train_size_initial:]


def sarima_forecast(tme_sries):
  sarima = SARIMAX(tme_sries, order=(1, 0, 2)).fit()
  return sarima.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_sa = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_sa['test'] = list(test_set)
evaluation_df_sa['forecast'] = evaluation_df_sa['forecast']\
  .apply(lambda n: sarima_forecast(df_final2['sleeps'].iloc[:train_size_initial + n]))
# Out:
# Date
# 2017-01-01    2657847
# 2017-02-01    3081026
# 2017-03-01    4015775
# 2017-04-01    5706131
# 2017-05-01    6002029
# 2017-06-01    6716372
# 2017-07-01    7841656
# 2017-08-01    9021656
# 2017-09-01    7194693
# Name: sleeps, dtype: int64
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %%
df_final2 ['sleeps'].iloc[df_final2.shape[0] - 50:].plot()
evaluation_df_sa.set_index(test_set.index)['forecast'].iloc[evaluation_df_sa.shape[0] - 50:].plot()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(evaluation_df_sa['test'], evaluation_df_sa['forecast'])
# Out:
# 1256066562129.5786

# %%
mean_squared_error(evaluation_df_ar['test'], evaluation_df_ar['forecast'])
# Out:
# 9546155571872.115

# %%
mean_squared_error(evaluation_df_es['test'], evaluation_df_es['forecast'])
# Out:
# 4701043741887.279

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df_final2 ['Earnings'])
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df_final2 ['sleeps'])
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df_final2 ['Guests'])
plt.show()

# %%
df_final2_2020 = df_final[df_final['Date']>= '2020-01-01'].sort_values(by='Date', ascending=True).set_index('Date')
df_final2_2020
# Out:
#                                               Type  Earnings   sleeps   Guests
# Date
# 2020-01-01  Turismo no espaço rural e de habitação      3727    59405    33826
# 2020-01-01                        Alojamento local     13531   432683   196084
# 2020-01-01                               Hotelaria    157454  2766138  1189595
# 2020-02-01                        Alojamento local     14675   481678   214985
# 2020-02-01                               Hotelaria    174634  3249008  1321936
# ...                                            ...       ...      ...      ...
# 2021-11-01                               Hotelaria    185160  2936910  1179545
# 2021-11-01                        Alojamento local     17907   511061   216257
# 2021-12-01                        Alojamento local     13590   399177   167868
# 2021-12-01  Turismo no espaço rural e de habitação      6645    98131    51125
# 2021-12-01                               Hotelaria    132228  2067266   897016
#
# ...

# %%
df_final2020 = df_final2_2020.groupby(['Date']).agg({'Earnings':'sum', 'sleeps':'sum', 'Guests':'sum'})

# %%
df_final2020 ['sleeps'].plot(figsize = (25,5))
df_final2020 ['sleeps'].rolling(7, min_periods = 2).mean().plot(figsize = (25,5))

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition_sleeps_2020 = sm.tsa.seasonal_decompose(x = df_final2020 ['sleeps'].rolling(11).mean().dropna(), period = 7, model='additive')
fig = decomposition_sleeps_2020.plot()
plt.show()

# %%
df_final2020
# Out:
#             Earnings   sleeps   Guests
# Date
# 2020-01-01    174712  3258226  1419505
# 2020-02-01    194422  3817043  1585501
# 2020-03-01     98452  1875506   681811
# 2020-04-01      4467   133212    46971
# 2020-05-01      9648   261593   126627
# 2020-06-01     53033  1031062   476660
# 2020-07-01    158799  2631261  1025974
# 2020-08-01    325165  5082349  1877772
# 2020-09-01    203622  3534350  1352118
# 2020-10-01    123586  2300257   990434
# 2020-11-01     46431   920058   398463
# 2020-12-01     53346   953382   448764
# 2021-01-01     32293   688039   296172
# 2021-02-01     18257   459904   202024
# 2021-03-01     26119   615727   274336
# 2021-04-01     47018   921028   446342
# 2021-05-01    125209  2024210   969144
# 2021-06-01    212214  3401792  1352387
# 2021-07-01    294080  4538643  1633781
# 2021-08-01    518772  7507272  2537993
# 2021-09-01    357142  5585513  2053453
# 2021-10-01    335700  5468960  2128258
# 2021-11-01    211006  3556760  1452112
# ...

# %%
decomposition_sleeps_final_2020 = sm.tsa.seasonal_decompose(x = (df_final2020 ['sleeps'] - decomposition_sleeps_2020.seasonal).dropna(), freq = 7, model='additive')
fig = decomposition_sleeps_final_2020.plot()
plt.plot()
# Out:
# <ipython-input-253-97d3e2aafb60>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition_sleeps_final_2020 = sm.tsa.seasonal_decompose(x = (df_final2020 ['sleeps'] - decomposition_sleeps_2020.seasonal).dropna(), freq = 7, model='additive')
# []

# %%
kpss(df_final2020['sleeps'], regression='c', nlags = 'auto')
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   Returns
# (0.21838367642587725,
#  0.1,
#  3,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
test_size_percentage = 0.25
test_size = int(test_size_percentage * df_final2020.shape[0])
train_size_initial = df_final2020.shape[0] - test_size

train_set = df_final2020['sleeps'].iloc[:train_size_initial]
test_set = df_final2020['sleeps'].iloc[train_size_initial:]


def expsm_forecast(tme_sries):
  es_2022= ExponentialSmoothing(tme_sries).fit(smoothing_level=0.1)
  return es_2022.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_es_2020 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_es_2020['test'] = list(test_set)
evaluation_df_es_2020['forecast'] = evaluation_df_es_2020['forecast']\
  .apply(lambda n: expsm_forecast(df_final2020['sleeps'].iloc[:train_size_initial + n]))
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/holtwinters/model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   return self._initialize_heuristic()
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   # Negative indices (that lie in the Index)
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# ...

# %%
df_final2020 ['sleeps'].plot()
evaluation_df_es_2020.set_index(test_set.index)['forecast'].plot()

# %%
test_size_percentage = 0.20
test_size = int(test_size_percentage * df_final2.shape[0])
train_size_initial = df_final2.shape[0] - test_size


train_set = df_final2020['sleeps'].iloc[:train_size_initial]
test_set = df_final2020['sleeps'].iloc[train_size_initial:]


def arima_forecast(tme_sries):
  arima_2020 = ARIMA(tme_sries, order=(1, 0, 2)).fit()
  return arima_2020.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_ar_2020 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_ar_2020['test'] = list(test_set)
evaluation_df_ar_2020['forecast'] = evaluation_df_ar_2020['forecast']\
  .apply(lambda n: arima_forecast(df_final2020['sleeps'].iloc[:train_size_initial + n]))
# Out:
# Date
# 2020-01-01    3258226
# 2020-02-01    3817043
# 2020-03-01    1875506
# 2020-04-01     133212
# 2020-05-01     261593
# 2020-06-01    1031062
# 2020-07-01    2631261
# 2020-08-01    5082349
# 2020-09-01    3534350
# 2020-10-01    2300257
# 2020-11-01     920058
# 2020-12-01     953382
# 2021-01-01     688039
# 2021-02-01     459904
# 2021-03-01     615727
# 2021-04-01     921028
# 2021-05-01    2024210
# 2021-06-01    3401792
# 2021-07-01    4538643
# 2021-08-01    7507272
# 2021-09-01    5585513
# 2021-10-01    5468960
# 2021-11-01    3556760
# 2021-12-01    2564574
# Name: sleeps, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-257-30f5fc2e45e2> in <module>
#      15 print(train_set)
#      16 evaluation_df_ar_2020 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
# ---> 17 evaluation_df_ar_2020['test'] = list(test_set)
# ...

# %%
test_size_percentage = 0.75
test_size = int(test_size_percentage * df_final2.shape[0])
train_size_initial = df_final2.shape[0] - test_size

train_set = df_final2020['sleeps'].iloc[:train_size_initial]
test_set = df_final2020['sleeps'].iloc[train_size_initial:]


def sarima_forecast(tme_sries):
  sarima_2020 = SARIMAX(tme_sries, order=(1, 0, 2)).fit()
  return sarima_2020.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_sa_2020 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_sa_2020['test'] = list(test_set)
evaluation_df_sa_2020['forecast'] = evaluation_df_sa_2020['forecast']\
  .apply(lambda n: sarima_forecast(df_final2020['sleeps'].iloc[:train_size_initial + n]))

# %%
sleeps_2022= pd.read_csv('https://raw.githubusercontent.com/LuisaPolicarpo/Project5/main/sleeps%202022.csv', encoding='latin-1', on_bad_lines='skip',sep=';')

# %%
df = sleeps_2022.drop(columns=['unwated', 'Unnamed: 3'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Período de referência dos dados   11 non-null     object
#  1    Dormidas                         11 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 304.0+ bytes

# %%
df_2 = df.rename(columns = {'Período de referência dos dados ':'Date',' Dormidas':'sleeps' })

# %%
df_2
# Out:
#                  Date   sleeps
# 0    Novembro de 2022  4246059
# 1     Outubro de 2022  6769497
# 2    Setembro de 2022  7664771
# 3      Agosto de 2022  9935751
# 4       Julho de 2022  8623586
# 5       Junho de 2022  7167299
# 6        Maio de 2022  6511175
# 7       Abril de 2022  6006236
# 8       Março de 2022  4006723
# 9   Fevereiro de 2022  2920471
# 10    Janeiro de 2022  1988869

# %%
df_2['Date'] = df_2['Date'].str.replace(' de ', '/')
df_2[['Month', 'Year']] = df_2['Date'].str.split('/',1,expand=True)
df_2
# Out:
#               Date   sleeps      Month  Year
# 0    Novembro/2022  4246059   Novembro  2022
# 1     Outubro/2022  6769497    Outubro  2022
# 2    Setembro/2022  7664771   Setembro  2022
# 3      Agosto/2022  9935751     Agosto  2022
# 4       Julho/2022  8623586      Julho  2022
# 5       Junho/2022  7167299      Junho  2022
# 6        Maio/2022  6511175       Maio  2022
# 7       Abril/2022  6006236      Abril  2022
# 8       Março/2022  4006723      Março  2022
# 9   Fevereiro/2022  2920471  Fevereiro  2022
# 10    Janeiro/2022  1988869    Janeiro  2022

# %%
months = {'Janeiro':'01', 'Fevereiro':'02', 'Março':'03', 'Abril':'04', 'Maio':'05', 'Junho':'06', 'Julho':'07', 'Agosto':'08', 'Setembro':'09', 'Outubro':10, 'Novembro':11, 'Dezembro':12}

df2=df_2.replace({"Month": months}) #convert the name to number of month
df2['Year'] = df2['Year'].astype(str)
df2['Month'] = df2['Month'].astype(str)
df2['Date'] = df2['Month']+df2['Year']

df_22 = df2[['Date', 'sleeps']]

df_22['Date'] = pd.to_datetime(df_22['Date'], format='%m%Y')
df_22 = df_22.sort_values('Date')
df_date = df_22.set_index('Date')
# Out:
# <ipython-input-374-46973bd4c99a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_22['Date'] = pd.to_datetime(df_22['Date'], format='%m%Y')

# %%
df_date
# Out:
#              sleeps
# Date
# 2022-01-01  1988869
# 2022-02-01  2920471
# 2022-03-01  4006723
# 2022-04-01  6006236
# 2022-05-01  6511175
# 2022-06-01  7167299
# 2022-07-01  8623586
# 2022-08-01  9935751
# 2022-09-01  7664771
# 2022-10-01  6769497
# 2022-11-01  4246059

# %%
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    11 non-null     datetime64[ns]
#  1   sleeps  11 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 304.0 bytes

# %%
df_final2
# Out:
#             Earnings   sleeps   Guests
# Date
# 2017-01-01    131933  2657847  1099252
# 2017-02-01    147256  3081026  1218329
# 2017-03-01    200851  4015775  1537326
# 2017-04-01    290595  5706131  2170641
# 2017-05-01    339481  6002029  2248329
# 2017-06-01    379140  6716372  2392536
# 2017-07-01    468826  7841656  2606509
# 2017-08-01    555291  9021656  2930910
# 2017-09-01    450722  7194693  2620090
# 2017-10-01    350786  6071385  2281543
# 2017-11-01    192382  3537490  1423707
# 2017-12-01    173945  3119681  1356400
# 2018-01-01    150151  2843739  1169618
# 2018-02-01    164730  3332670  1326917
# 2018-03-01    241219  4571119  1773889
# 2018-04-01    303450  5374612  2099720
# 2018-05-01    379953  6302074  2421499
# 2018-06-01    416793  6743203  2473840
# 2018-07-01    506304  7974521  2678035
# 2018-08-01    592252  9292740  3103645
# 2018-09-01    467515  7342627  2736676
# 2018-10-01    368121  6250714  2376320
# 2018-11-01    208399  3791610  1558139
# ...

# %%
df_final_all = df_final.groupby(['Date']).agg({'Earnings':'sum', 'sleeps':'sum', 'Guests':'sum'})

# %%
df_final_all
# Out:
#             Earnings   sleeps   Guests
# Date
# 2017-01-01    131933  2657847  1099252
# 2017-02-01    147256  3081026  1218329
# 2017-03-01    200851  4015775  1537326
# 2017-04-01    290595  5706131  2170641
# 2017-05-01    339481  6002029  2248329
# 2017-06-01    379140  6716372  2392536
# 2017-07-01    468826  7841656  2606509
# 2017-08-01    555291  9021656  2930910
# 2017-09-01    450722  7194693  2620090
# 2017-10-01    350786  6071385  2281543
# 2017-11-01    192382  3537490  1423707
# 2017-12-01    173945  3119681  1356400
# 2018-01-01    150151  2843739  1169618
# 2018-02-01    164730  3332670  1326917
# 2018-03-01    241219  4571119  1773889
# 2018-04-01    303450  5374612  2099720
# 2018-05-01    379953  6302074  2421499
# 2018-06-01    416793  6743203  2473840
# 2018-07-01    506304  7974521  2678035
# 2018-08-01    592252  9292740  3103645
# 2018-09-01    467515  7342627  2736676
# 2018-10-01    368121  6250714  2376320
# 2018-11-01    208399  3791610  1558139
# ...

# %%
df_sleeps = df_final_all.drop(columns=['Earnings',	'Guests'])

# %%
df_sleeps
# Out:
#              sleeps
# Date
# 2017-01-01  2657847
# 2017-02-01  3081026
# 2017-03-01  4015775
# 2017-04-01  5706131
# 2017-05-01  6002029
# 2017-06-01  6716372
# 2017-07-01  7841656
# 2017-08-01  9021656
# 2017-09-01  7194693
# 2017-10-01  6071385
# 2017-11-01  3537490
# 2017-12-01  3119681
# 2018-01-01  2843739
# 2018-02-01  3332670
# 2018-03-01  4571119
# 2018-04-01  5374612
# 2018-05-01  6302074
# 2018-06-01  6743203
# 2018-07-01  7974521
# 2018-08-01  9292740
# 2018-09-01  7342627
# 2018-10-01  6250714
# 2018-11-01  3791610
# 2018-12-01  3256830
# 2019-01-01  3034284
# 2019-02-01  3365240
# 2019-03-01  4606922
# 2019-04-01  5981300
# 2019-05-01  6557840
# 2019-06-01  7177554
# 2019-07-01  8231230
# 2019-08-01  9633427
# 2019-09-01  7624574
# 2019-10-01  6358685
# 2019-11-01  4071968
# 2019-12-01  3515940
# 2020-01-01  3258226
# 2020-02-01  3817043
# 2020-03-01  1875506
# 2020-04-01   133212
# 2020-05-01   261593
# 2020-06-01  1031062
# 2020-07-01  2631261
# 2020-08-01  5082349
# ...

# %%
df_22
# Out:
#          Date   sleeps
# 0  2022-11-01  4246059
# 1  2022-10-01  6769497
# 2  2022-09-01  7664771
# 3  2022-08-01  9935751
# 4  2022-07-01  8623586
# 5  2022-06-01  7167299
# 6  2022-05-01  6511175
# 7  2022-04-01  6006236
# 8  2022-03-01  4006723
# 9  2022-02-01  2920471
# 10 2022-01-01  1988869

# %%
df_final_2017_2022= pd.concat([df_sleeps, df_date], axis=0)

# %%
df_final_2017_2022
# Out:
#              sleeps
# Date
# 2017-01-01  2657847
# 2017-02-01  3081026
# 2017-03-01  4015775
# 2017-04-01  5706131
# 2017-05-01  6002029
# ...             ...
# 2022-05-01  6511175
# 2022-04-01  6006236
# 2022-03-01  4006723
# 2022-02-01  2920471
# 2022-01-01  1988869
#
# [71 rows x 1 columns]

# %%
df_final_2017_2022.to_csv('df_final_2017_2022.csv') 
files.download('df_final_2017_2022.csv')

# %% [markdown]
# **2017-2022**

# %%
rcParams['figure.figsize'] = 18, 8
decomposition_sleeps_2017_2022 = sm.tsa.seasonal_decompose(x = df_final_2017_2022['sleeps'].rolling(12).mean().dropna(), period = 6, model='additive')
fig = decomposition_sleeps_2017_2022.plot()
plt.show()

# %%
decomposition_sleeps_2017_2022_final = sm.tsa.seasonal_decompose(x = (df_final_2017_2022 ['sleeps'] - decomposition_sleeps_2017_2022.seasonal).dropna(), freq = 28, model='additive')
fig = decomposition_sleeps_2017_2022_final.plot()
plt.plot()
# Out:
# <ipython-input-383-7b16fdf0f99e>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition_sleeps_2017_2022_final = sm.tsa.seasonal_decompose(x = (df_final_2017_2022 ['sleeps'] - decomposition_sleeps_2017_2022.seasonal).dropna(), freq = 28, model='additive')
# []

# %%
autocorrelation_plot(df_final_2017_2022 ['sleeps'].dropna())
plt.show()

# %%
auto_arima(train_set)
# Out:
# ARIMA(order=(3, 1, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
test_size_percentage = 0.25
test_size = int(test_size_percentage * df_final_2017_2022.shape[0])
train_size_initial = df_final_2017_2022.shape[0] - test_size

train_set = df_final_2017_2022['sleeps'].iloc[:train_size_initial]
test_set = df_final_2017_2022['sleeps'].iloc[train_size_initial:]


def expsm_forecast(tme_sries):
  es_1722 = ExponentialSmoothing(tme_sries).fit(smoothing_level=0.1)
  return es_1722.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_es_1722 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_es_1722['test'] = list(test_set)
evaluation_df_es_1722['forecast'] = evaluation_df_es_1722['forecast']\
  .apply(lambda n: expsm_forecast(df_final_2017_2022.iloc[:train_size_initial + n]))
# Out:
# Date
# 2017-01-01    2657847
# 2017-02-01    3081026
# 2017-03-01    4015775
# 2017-04-01    5706131
# 2017-05-01    6002029
# 2017-06-01    6716372
# 2017-07-01    7841656
# 2017-08-01    9021656
# 2017-09-01    7194693
# 2017-10-01    6071385
# 2017-11-01    3537490
# 2017-12-01    3119681
# 2018-01-01    2843739
# 2018-02-01    3332670
# 2018-03-01    4571119
# 2018-04-01    5374612
# 2018-05-01    6302074
# 2018-06-01    6743203
# 2018-07-01    7974521
# 2018-08-01    9292740
# 2018-09-01    7342627
# 2018-10-01    6250714
# 2018-11-01    3791610
# 2018-12-01    3256830
# 2019-01-01    3034284
# 2019-02-01    3365240
# 2019-03-01    4606922
# 2019-04-01    5981300
# 2019-05-01    6557840
# 2019-06-01    7177554
# 2019-07-01    8231230
# 2019-08-01    9633427
# 2019-09-01    7624574
# 2019-10-01    6358685
# 2019-11-01    4071968
# 2019-12-01    3515940
# 2020-01-01    3258226
# 2020-02-01    3817043
# 2020-03-01    1875506
# 2020-04-01     133212
# 2020-05-01     261593
# ...

# %%
df_final_2017_2022 ['sleeps'].plot()
evaluation_df_es_1722.set_index(test_set.index)['forecast'].plot()

# %%
test_size_percentage = 0.25
test_size = int(test_size_percentage * df_final_2017_2022.shape[0])
train_size_initial = df_final_2017_2022.shape[0] - test_size

train_set = df_final_2017_2022['sleeps'].iloc[:train_size_initial]
test_set = df_final_2017_2022['sleeps'].iloc[train_size_initial:]


def arima_forecast(tme_sries):
  arima1722 = ARIMA(tme_sries, order=(3, 1, 1)).fit()
  return arima1722.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_ar_1722 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_ar_1722['test'] = list(test_set)
evaluation_df_ar_1722['forecast'] = evaluation_df_ar_1722['forecast']\
  .apply(lambda n: arima_forecast(df_final_2017_2022['sleeps'].iloc[:train_size_initial + n]))
# Out:
# Date
# 2017-01-01    2657847
# 2017-02-01    3081026
# 2017-03-01    4015775
# 2017-04-01    5706131
# 2017-05-01    6002029
# 2017-06-01    6716372
# 2017-07-01    7841656
# 2017-08-01    9021656
# 2017-09-01    7194693
# 2017-10-01    6071385
# 2017-11-01    3537490
# 2017-12-01    3119681
# 2018-01-01    2843739
# 2018-02-01    3332670
# 2018-03-01    4571119
# 2018-04-01    5374612
# 2018-05-01    6302074
# 2018-06-01    6743203
# 2018-07-01    7974521
# 2018-08-01    9292740
# 2018-09-01    7342627
# 2018-10-01    6250714
# 2018-11-01    3791610
# 2018-12-01    3256830
# 2019-01-01    3034284
# 2019-02-01    3365240
# 2019-03-01    4606922
# 2019-04-01    5981300
# 2019-05-01    6557840
# 2019-06-01    7177554
# 2019-07-01    8231230
# 2019-08-01    9633427
# 2019-09-01    7624574
# 2019-10-01    6358685
# 2019-11-01    4071968
# 2019-12-01    3515940
# 2020-01-01    3258226
# 2020-02-01    3817043
# 2020-03-01    1875506
# 2020-04-01     133212
# 2020-05-01     261593
# ...

# %%
test_size_percentage = 0.75
test_size = int(test_size_percentage * df_final_2017_2022.shape[0])
train_size_initial = df_final_2017_2022.shape[0] - test_size

train_set = df_final_2017_2022['sleeps'].iloc[:train_size_initial]
test_set = df_final_2017_2022['sleeps'].iloc[train_size_initial:]


def sarima_forecast(tme_sries):
  sarima_1722 = SARIMAX(tme_sries, order=(1, 0, 2)).fit()
  return sarima_1722.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_sa_1722 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_sa_1722['test'] = list(test_set)
evaluation_df_sa_1722['forecast'] = evaluation_df_sa_1722['forecast']\
  .apply(lambda n: sarima_forecast(df_final_2017_2022['sleeps'].iloc[:train_size_initial + n]))
# Out:
# Date
# 2017-01-01    2657847
# 2017-02-01    3081026
# 2017-03-01    4015775
# 2017-04-01    5706131
# 2017-05-01    6002029
# 2017-06-01    6716372
# 2017-07-01    7841656
# 2017-08-01    9021656
# 2017-09-01    7194693
# 2017-10-01    6071385
# 2017-11-01    3537490
# 2017-12-01    3119681
# 2018-01-01    2843739
# 2018-02-01    3332670
# 2018-03-01    4571119
# 2018-04-01    5374612
# 2018-05-01    6302074
# 2018-06-01    6743203
# Name: sleeps, dtype: int64
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# ...

# %%
mean_squared_error(evaluation_df_ar_1722['test'], evaluation_df_ar_1722['forecast']) #15
# Out:
# 1894891792475.9614

# %%
mean_squared_error(evaluation_df_es_1722['test'], evaluation_df_es_1722['forecast']) #13
# Out:
# 7433020221565.37

# %%
mean_squared_error(evaluation_df_sa_1722['test'], evaluation_df_sa_1722['forecast']) #13
# Out:
# 1553919964614.4805

# %%
df_final_2017_2022 ['sleeps'].plot()
evaluation_df_sa_1722.set_index(test_set.index)['forecast'].plot()

# %% [markdown]
# **2020-2022**

# %%
df_final_2020_2022 = df_final_2017_2022.iloc[36::]

# %%
rcParams['figure.figsize'] = 18, 8
decomposition_sleeps_2220 = sm.tsa.seasonal_decompose(x = df_final_2020_2022['sleeps'].rolling(12).mean().dropna(), period = 7, model='additive')
fig = decomposition_sleeps_2220.plot()
plt.show()

# %%
decomposition_sleeps_2220_final = sm.tsa.seasonal_decompose(x = (df_final_2020_2022 ['sleeps'] - decomposition_sleeps_2220.seasonal).dropna(), freq = 10, model='additive')
fig = decomposition_sleeps_2220_final.plot()
plt.plot()
# Out:
# <ipython-input-414-87148bfcbd18>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition_sleeps_2220_final = sm.tsa.seasonal_decompose(x = (df_final_2020_2022 ['sleeps'] - decomposition_sleeps_2220.seasonal).dropna(), freq = 10, model='additive')
# []

# %%
auto_arima(train_set)
# Out:
# ARIMA(order=(3, 0, 0), scoring_args={}, suppress_warnings=True)

# %%
test_size_percentage = 0.25
test_size = int(test_size_percentage * df_final_2020_2022.shape[0])
train_size_initial = df_final_2020_2022.shape[0] - test_size

train_set = df_final_2020_2022['sleeps'].iloc[:train_size_initial]
test_set = df_final_2020_2022['sleeps'].iloc[train_size_initial:]


def arima_forecast(tme_sries):
  arima2220 = ARIMA(tme_sries, order=(3, 0, 0)).fit()
  return arima2220.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_ar_2220 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_ar_2220['test'] = list(test_set)
evaluation_df_ar_2220['forecast'] = evaluation_df_ar_2220['forecast']\
  .apply(lambda n: arima_forecast(df_final_2020_2022['sleeps'].iloc[:train_size_initial + n]))
# Out:
# Date
# 2020-01-01    3258226
# 2020-02-01    3817043
# 2020-03-01    1875506
# 2020-04-01     133212
# 2020-05-01     261593
# 2020-06-01    1031062
# 2020-07-01    2631261
# 2020-08-01    5082349
# 2020-09-01    3534350
# 2020-10-01    2300257
# 2020-11-01     920058
# 2020-12-01     953382
# 2021-01-01     688039
# 2021-02-01     459904
# 2021-03-01     615727
# 2021-04-01     921028
# 2021-05-01    2024210
# 2021-06-01    3401792
# 2021-07-01    4538643
# 2021-08-01    7507272
# 2021-09-01    5585513
# 2021-10-01    5468960
# 2021-11-01    3556760
# 2021-12-01    2564574
# 2022-01-01    1988869
# 2022-02-01    2920471
# 2022-03-01    4006723
# Name: sleeps, dtype: int64
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# ...

# %%
test_size_percentage = 0.25
test_size = int(test_size_percentage * df_final_2020_2022.shape[0])
train_size_initial = df_final_2020_2022.shape[0] - test_size

train_set = df_final_2020_2022['sleeps'].iloc[:train_size_initial]
test_set = df_final_2020_2022['sleeps'].iloc[train_size_initial:]


def expsm_forecast(tme_sries):
  es_2220 = ExponentialSmoothing(tme_sries).fit(smoothing_level=0.1)
  return es_2220.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_es_2220 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_es_2220['test'] = list(test_set)
evaluation_df_es_2220['forecast'] = evaluation_df_es_2220['forecast']\
  .apply(lambda n: expsm_forecast(df_final_2020_2022.iloc[:train_size_initial + n]))
# Out:
# Date
# 2020-01-01    3258226
# 2020-02-01    3817043
# 2020-03-01    1875506
# 2020-04-01     133212
# 2020-05-01     261593
# 2020-06-01    1031062
# 2020-07-01    2631261
# 2020-08-01    5082349
# 2020-09-01    3534350
# 2020-10-01    2300257
# 2020-11-01     920058
# 2020-12-01     953382
# 2021-01-01     688039
# 2021-02-01     459904
# 2021-03-01     615727
# 2021-04-01     921028
# 2021-05-01    2024210
# 2021-06-01    3401792
# 2021-07-01    4538643
# 2021-08-01    7507272
# 2021-09-01    5585513
# 2021-10-01    5468960
# 2021-11-01    3556760
# 2021-12-01    2564574
# 2022-01-01    1988869
# 2022-02-01    2920471
# 2022-03-01    4006723
# Name: sleeps, dtype: int64
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# ...

# %%
test_size_percentage = 0.75
test_size = int(test_size_percentage * df_final_2020_2022.shape[0])
train_size_initial = df_final_2020_2022.shape[0] - test_size

train_set = df_final_2020_2022['sleeps'].iloc[:train_size_initial]
test_set = df_final_2020_2022['sleeps'].iloc[train_size_initial:]


def sarima_forecast(tme_sries):
  sarima_2022 = SARIMAX(tme_sries, order=(3, 0, 0)).fit()
  return sarima_2022.forecast().iloc[0]
# arima_forecast(train_set)

print(train_set)
evaluation_df_sa_2022 = pd.DataFrame(range(0, test_size), columns = ['forecast'])
evaluation_df_sa_2022['test'] = list(test_set)
evaluation_df_sa_2022['forecast'] = evaluation_df_sa_2022['forecast']\
  .apply(lambda n: sarima_forecast(df_final_2020_2022['sleeps'].iloc[:train_size_initial + n]))
# Out:
# Date
# 2020-01-01    3258226
# 2020-02-01    3817043
# 2020-03-01    1875506
# 2020-04-01     133212
# 2020-05-01     261593
# 2020-06-01    1031062
# 2020-07-01    2631261
# 2020-08-01    5082349
# 2020-09-01    3534350
# Name: sleeps, dtype: int64
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   # If an index is available, see if it is a date-based index or if it
# ...

# %%
mean_squared_error(evaluation_df_sa_2022['test'], evaluation_df_sa_2022['forecast']) #13
# Out:
# 2133703188573.9514

# %%
mean_squared_error(evaluation_df_ar_2220['test'], evaluation_df_ar_2220['forecast']) #13
# Out:
# 2319566781594.282

# %%
mean_squared_error(evaluation_df_es_2220['test'], evaluation_df_es_2220['forecast']) #14
# Out:
# 11204805053771.922

# %%
df_final_2020_2022 ['sleeps'].plot()
evaluation_df_sa_2022.set_index(test_set.index)['forecast'].plot()
